# %%
import pandas as pd
from matplotlib import pyplot as plt

# allow pandas to mtplotlib conversion
from pandas import plotting as converter
converter.register_matplotlib_converters()

# %%
IDT_DATETIME_FORMAT = "%Y-%m-%dT%H:%M:%S.%f%z"

def format_dsco2(data):
    data.columns = ["timestamp", "ppm_co2"]
    data.timestamp = pd.to_datetime(data.timestamp, unit='s')
    return data

def format_idt(data):
    rename_dict = {"start_time": "timestamp", "eCO2 (ppm)": "ppm_co2"}
    data = data.rename(columns=rename_dict)
    data = data[data.ppm_co2 != 0]
    data.timestamp = data.timestamp + "+0500"
    data.timestamp = pd.to_datetime(data.timestamp, format=IDT_DATETIME_FORMAT)
    return data

# %% [markdown]
# ## Load and display DS-CO2-20

# %%
dsco21 = pd.read_csv("ds-co2-20/s1-1.csv")
dsco21 = format_dsco2(dsco21)
dsco21.head()
# Out:
#                       timestamp  ppm_co2
# 0 2020-04-08 11:07:13.317976475     46.1
# 1 2020-04-08 11:07:14.319091797     46.1
# 2 2020-04-08 11:07:15.315467596     46.2
# 3 2020-04-08 11:07:16.317836523     46.2
# 4 2020-04-08 11:07:17.312409878     46.2

# %%
dsco21.shape
# Out:
# (13528, 2)

# %%
plt.figure(figsize=(20,5))
plt.plot(dsco21.timestamp, dsco21.ppm_co2, 'b')

# %%
idt1 = pd.read_csv("idt/s2-1.csv")
idt1 = format_idt(idt1)
idt1.head()
# Out:
#    board_type    sequence  sleeptime   run                        timestamp  \
# 15  IDT HiCom  hard coded        0.0  16.0 2020-04-07 00:14:12.898000+05:00
# 16  IDT HiCom  hard coded        0.0  17.0 2020-04-07 00:14:14.903000+05:00
# 17  IDT HiCom  hard coded        0.0  18.0 2020-04-07 00:14:16.918000+05:00
# 18  IDT HiCom  hard coded        0.0  19.0 2020-04-07 00:14:18.938000+05:00
# 19  IDT HiCom  hard coded        0.0  20.0 2020-04-07 00:14:20.940000+05:00
#
#       device_tracking making_code   Rhtr_RT  \
# 15  x0000463C53845B75       x2310  22.39095
# 16  x0000463C53845B75       x2310  22.39095
# 17  x0000463C53845B75       x2310  22.39095
# 18  x0000463C53845B75       x2310  22.39095
# 19  x0000463C53845B75       x2310  22.39095
#
#                                        generalpurpose      VDDH  ...  Wait1  \
# 15  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.081041  ...    1.0
# 16  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.081041  ...    1.0
# 17  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.081041  ...    1.0
# 18  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.081041  ...    1.0
# 19  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.081041  ...    1.0
#
#     Temp2  Wait2   Rmox_Temp1   Rmox_Temp2  comment  EtOH (ppm)  IAQ  \
# 15  300.0    1.0  7068.267437  7209.744755      NaN         0.0  0.0
# 16  300.0    1.0  7374.396220  7612.240576      NaN         0.0  0.0
# 17  300.0    1.0  7773.656882  7946.868869      NaN         0.0  0.0
# 18  300.0    1.0  8166.666667  8344.370861      NaN         0.0  0.0
# 19  300.0    1.0  8456.550625  8661.866931      NaN         0.0  0.0
#
#     TVOC (mg/m^3)  ppm_co2
# 15            0.0    400.0
# 16            0.0    400.0
# 17            0.0    400.0
# 18            0.0    400.0
# 19            0.0    400.0
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(20,5))
plt.plot(idt1.timestamp, idt1.ppm_co2, 'r')

# %%
plt.figure(figsize=(20,5))
plt.plot(idt1.timestamp, idt1.ppm_co2, 'r')
plt.plot(dsco21.timestamp, dsco21.ppm_co2, 'b')

# %% [markdown]
# ## Analize Segment 2

# %%
dsco22 = pd.read_csv("ds-co2-20/s1-2.csv")
dsco22 = format_dsco2(dsco22)
dsco22.head()
# Out:
#                       timestamp  ppm_co2
# 0 2020-04-06 21:10:25.030733109    525.9
# 1 2020-04-06 21:10:26.028914928    525.9
# 2 2020-04-06 21:10:27.026957750    524.9
# 3 2020-04-06 21:10:28.025394440    525.9
# 4 2020-04-06 21:10:29.023691416    525.9

# %%
dsco22.shape
# Out:
# (7357, 2)

# %%
plt.figure(figsize=(20,5))
plt.plot(dsco22.timestamp, dsco22.ppm_co2, 'b')

# %%
idt2 = pd.read_csv("idt/s2-2.csv")
idt2 = format_idt(idt2)
idt2.head()
# Out:
#    board_type    sequence  sleeptime   run                        timestamp  \
# 15  IDT HiCom  hard coded        0.0  16.0 2020-04-07 02:13:09.824000+05:00
# 16  IDT HiCom  hard coded        0.0  17.0 2020-04-07 02:13:11.833000+05:00
# 17  IDT HiCom  hard coded        0.0  18.0 2020-04-07 02:13:13.842000+05:00
# 18  IDT HiCom  hard coded        0.0  19.0 2020-04-07 02:13:15.867000+05:00
# 19  IDT HiCom  hard coded        0.0  20.0 2020-04-07 02:13:17.880000+05:00
#
#       device_tracking making_code    Rhtr_RT  \
# 15  x0000463C53845B75       x2310  22.325344
# 16  x0000463C53845B75       x2310  22.325344
# 17  x0000463C53845B75       x2310  22.325344
# 18  x0000463C53845B75       x2310  22.325344
# 19  x0000463C53845B75       x2310  22.325344
#
#                                        generalpurpose      VDDH  ...  Wait1  \
# 15  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080143  ...    1.0
# 16  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080143  ...    1.0
# 17  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080143  ...    1.0
# 18  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080143  ...    1.0
# 19  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080143  ...    1.0
#
#     Temp2  Wait2    Rmox_Temp1    Rmox_Temp2  comment  EtOH (ppm)  IAQ  \
# 15  300.0    1.0  44032.676776  45062.681010      NaN         0.0  0.0
# 16  300.0    1.0  45978.782154  47217.690623      NaN         0.0  0.0
# 17  300.0    1.0  47933.350069  48685.563225      NaN         0.0  0.0
# 18  300.0    1.0  49879.647585  50610.217497      NaN         0.0  0.0
# 19  300.0    1.0  51411.398041  52373.757794      NaN         0.0  0.0
#
#     TVOC (mg/m^3)  ppm_co2
# 15            0.0    400.0
# 16            0.0    400.0
# 17            0.0    400.0
# 18            0.0    400.0
# 19            0.0    400.0
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(20,5))
plt.plot(idt2.timestamp, idt2.ppm_co2, 'r')

# %%
plt.figure(figsize=(20,5))
plt.plot(idt2.timestamp, idt2.ppm_co2, 'r')
plt.plot(dsco22.timestamp, dsco22.ppm_co2, 'b')

# %% [markdown]
# ## Analize Segment 4

# %%
dsco24 = pd.read_csv("ds-co2-20/s1-4.csv")
dsco24 = format_dsco2(dsco24)
dsco24.head()
# Out:
#                       timestamp  ppm_co2
# 0 2020-04-07 03:23:04.592004776    807.3
# 1 2020-04-07 03:23:05.589532375    808.3
# 2 2020-04-07 03:23:06.587002516    808.3
# 3 2020-04-07 03:23:07.584398031    808.2
# 4 2020-04-07 03:23:08.582127810    809.2

# %%
dsco24.shape
# Out:
# (25338, 2)

# %%
plt.figure(figsize=(20,5))
plt.plot(dsco24.timestamp, dsco24.ppm_co2, 'b')

# %%
idt4 = pd.read_csv("idt/s2-4.csv")
idt4 = format_idt(idt4)
idt4.head()
# Out:
#    board_type    sequence  sleeptime   run                        timestamp  \
# 15  IDT HiCom  hard coded        0.0  16.0 2020-04-07 08:21:45.114000+05:00
# 16  IDT HiCom  hard coded        0.0  17.0 2020-04-07 08:21:47.141000+05:00
# 17  IDT HiCom  hard coded        0.0  18.0 2020-04-07 08:21:49.146000+05:00
# 18  IDT HiCom  hard coded        0.0  19.0 2020-04-07 08:21:51.155000+05:00
# 19  IDT HiCom  hard coded        0.0  20.0 2020-04-07 08:21:53.169000+05:00
#
#       device_tracking making_code    Rhtr_RT  \
# 15  x0000463C53845B75       x2310  22.465303
# 16  x0000463C53845B75       x2310  22.465303
# 17  x0000463C53845B75       x2310  22.465303
# 18  x0000463C53845B75       x2310  22.465303
# 19  x0000463C53845B75       x2310  22.465303
#
#                                        generalpurpose      VDDH  ...  Wait1  \
# 15  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080464  ...    1.0
# 16  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080464  ...    1.0
# 17  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080464  ...    1.0
# 18  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080464  ...    1.0
# 19  [200, 2, 167, 6, 210, 0, 0, 0, 0, 0, 0, 0, 0, ...  2.080464  ...    1.0
#
#     Temp2  Wait2    Rmox_Temp1    Rmox_Temp2  comment  EtOH (ppm)  IAQ  \
# 15  300.0    1.0  41354.425735  42362.765566      NaN         0.0  0.0
# 16  300.0    1.0  43311.556240  44283.239498      NaN         0.0  0.0
# 17  300.0    1.0  45320.549988  46403.676593      NaN         0.0  0.0
# 18  300.0    1.0  47077.269505  47759.799310      NaN         0.0  0.0
# 19  300.0    1.0  48858.330534  49796.460177      NaN         0.0  0.0
#
#     TVOC (mg/m^3)  ppm_co2
# 15            0.0    400.0
# 16            0.0    400.0
# 17            0.0    400.0
# 18            0.0    400.0
# 19            0.0    400.0
#
# [5 rows x 27 columns]

# %%
plt.figure(figsize=(20,5))
plt.plot(idt4.timestamp, idt4.ppm_co2, 'r')

# %%
plt.figure(figsize=(20,5))
plt.plot(idt4.timestamp, idt4.ppm_co2, 'r')
plt.plot(dsco24.timestamp, dsco24.ppm_co2, 'b')

# %%
plt.figure(figsize=(20,5))
plt.plot(idt1.timestamp, idt1.ppm_co2, 'r')
plt.plot(dsco21.timestamp, dsco21.ppm_co2, 'b')
plt.plot(idt2.timestamp, idt2.ppm_co2, 'r')
plt.plot(dsco22.timestamp, dsco22.ppm_co2, 'b')
plt.plot(idt4.timestamp, idt4.ppm_co2, 'r')
plt.plot(dsco24.timestamp, dsco24.ppm_co2, 'b')
